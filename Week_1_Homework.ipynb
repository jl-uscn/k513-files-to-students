# %% [markdown]
# # K513 · Week 1 Homework
# ## What is actually in this table?
#
# This assignment covers both of this week's sessions. You will open a dataset nobody has walked you
# through, work out what is in it, and then say — in writing — what you would and would not trust it
# for. That second half is the assignment.
#
# **The dataset.** `world_indicators_2010.csv` — 208 countries and territories, 24 columns of World
# Bank indicators for 2010. One row is one country.
#
# **What gets graded.** Five short numeric checks that confirm your code ran, three written answers,
# and one Analyst's Note. The code matters because it produces the numbers, but the numbers are not
# the deliverable — what you conclude from them is.
#
# **Where the answers go.** Not in this notebook — in the Canvas quiz **Week 1 Homework - Data Understanding**. Work them out here,
# then write them there. Nothing typed into this notebook is collected, so an answer left here scores
# zero.
#
# **Due Sunday 11:59 pm.** Submit the Canvas quiz, and paste a link to this notebook into its first
# question.
#
# ---
# ### Before you type anything
#
# **File → Save a copy in Drive.**
#
# This notebook is read-only for you. You can type into it and run it and it will look completely
# normal, but nothing you do will be saved. Save your own copy first, every time.
#
# ---
#
# ### Using AI in this notebook
#
# Gemini is built into Colab and you are welcome to use it here. Two things worth knowing:
#
# - It does not know which columns you have or what we covered in class. Whatever it writes, you own.
# - The most useful thing you can ask it is **"explain what this line does"** — not "write it for me".
#
# AI will also write code cells out of order and leave redundant ones behind. **Clean the notebook
# before you submit it.** A notebook that only runs top to bottom if you know which cells to skip is
# not a finished piece of work.
#
# The specific trap this week is Part 3. Ask an AI what is wrong with a column and it will
# give you a fluent, general answer about data quality — because it cannot see your table. The two
# columns in Part 3 look like the same problem and are not. Only the output in front of you can tell
# you which is which.
#
# ---
#
# ### Turn off Unwanted AI Assistance
#
# AI-powered coding completion is turned on by default. It is convenient but does not give you a chance
# to think and learn. Turning it off helps you learn. You can always turn it back on when needed.
# - Tools → settings → AI Assistance → Uncheck "Show AI-powered inline code completions"
# - Tools → settings → Uncheck "Show context-powered code completions"
#
# ---
#
# ### How to run a cell
#
# Click on a cell, then press **Shift + Enter**. That runs it and moves you to the next one. If
# anything ever looks wrong: **Runtime → Restart session and run all**.

# %% [markdown]
# ---
# ## 0 · Setup
#
# Run both cells. Nothing here needs changing.

# %%
import pandas as pd

pd.set_option('display.precision', 3)
pd.set_option('display.max_columns', None)

# %%
WORLD_URL = "https://raw.githubusercontent.com/jl-uscn/k513-data/main/world_indicators_2010.csv"

world_df = pd.read_csv(WORLD_URL)
world_df.head()

# %% [markdown]
# ---
# # Part 1 · What is in this table?
#
# Four one-liners, in the order you would actually run them. Say the shape out loud.

# %%
world_df.shape

# %% [markdown]
# `.info()` is the one people skim. Do not skim it. It carries three separate facts: how many
# rows there are, which columns hold text rather than numbers, and — in the **Non-Null Count** column
# — how complete each variable is.
#
# Read the Non-Null Count against the row count from `.shape` above. **Canvas question 2** asks how
# many of the 24 columns are complete, meaning nothing is missing at all.

# %%
world_df.info()

# %% [markdown]
# Now `.describe()`. **Canvas question 1** asks how many columns come back.
#
# Twenty-four went in. Count what comes out, and work out which ones did not survive and why. This is
# the same thing that happened to the bike-share table in class.

# %%
world_df.describe()

# %% [markdown]
# One text column is worth a proper look on its own. **Canvas question 3** asks how many
# countries are in Europe.

# %%
world_df['Region'].value_counts()

# %% [markdown]
# ---
# # Part 2 · Reading one variable
#
# `Population (M)` is population in millions. It is one of only a handful of columns with no missing
# values, so nothing here is complicated by gaps — which makes it a clean place to practice the four
# questions.
#
# Ask them in order.

# %%
world_df['Population (M)'].describe()

# %% [markdown]
# Fill in the column name. **Canvas question 4** asks for this number, rounded to three
# decimal places.

# %%
world_df['____'].skew()

# %% [markdown]
# Draw it. Pick a `bins` value, look at it, then **change `bins` and look again** — that is
# the move from class, not the number you happened to choose first. A shape that survives the change
# is in the data.

# %%
world_df['Population (M)'].plot(kind='hist', bins=____)

# %% [markdown]
# A histogram of a column like this tells you there is something at the far right without
# telling you *what*. Sorting does. Descending order puts the extreme end at the top.

# %%
world_df.sort_values(by='____', ascending=False).head(10)

# %% [markdown]
# **(a)** Answer the four questions for `Population (M)`, using the output above. One short
# paragraph, not four bullet points — and finish with the sentence you would actually write in a
# report if you had to give a single number for the population of a typical country in this table.
#
# **The four questions to ask of any variable** *(Week 1 Session 2)*:
#
# - **Center** — where is it?
# - **Spread** — how far out does it go?
# - **Shape** — is it symmetric, or does it lean?
# - **Outliers** — is anything a long way from everything else?
#
# > ✏️ **Answer in Canvas** — *Week 1 Homework - Data Understanding*, question **(a)**.

# %% [markdown]
# ---
# # Part 3 · Two columns that are not what they look like
#
# Both of the columns below have something odd at one end. **They are not the same kind of odd**, and
# telling them apart is the whole of this part.
#
# Start with `Internet Usage` — the share of the population using the internet, as a proportion.
# **Canvas question 5** asks how many countries have it recorded as exactly 0.0.

# %%
world_df['____'].value_counts()

# %% [markdown]
# Look at that list before you draw anything. How many **distinct** values are there, across
# how many countries? A column of proportions could in principle take any value between 0 and 1.
#
# Now draw it.

# %%
world_df['Internet Usage'].plot(kind='hist', bins=20)

# %% [markdown]
# Second column: `Population Urban %`, the share of the population living in urban areas.

# %%
world_df['Population Urban %'].plot(kind='hist', bins=20)

# %% [markdown]
# There is a bar hard against the right-hand edge. A histogram will not tell you what is in
# it — go and look at the rows.

# %%
world_df.sort_values(by='Population Urban %', ascending=False).head(10)

# %% [markdown]
# **(b)** Both columns have a pile of values at one extreme. **One of them is a recording
# problem and one of them is a fact about the world.**
#
# Say which is which, name the evidence in your own output that decides it, and say what you would do
# about the recording problem if you had to report on that column next week.
#
# *Four or five sentences. This is the most important written answer in the assignment.*
#
# > ✏️ **Answer in Canvas** — *Week 1 Homework - Data Understanding*, question **(b)**.

# %% [markdown]
# ---
# # Part 4 · One row is one what?
#
# One picture of two columns at once, and then the question the whole week has been building to.
#
# Fill in the two column names: put `Health Exp/Capita` on the horizontal axis and
# `Life Expectancy Female` on the vertical one. In class the rule was **`x` explains, `y` is
# explained**.

# %%
world_df.plot(kind='scatter', x='____', y='____')

# %% [markdown]
# **(c)** Three things, briefly.
#
# 1. **What does each row represent in this table?** Say it in a sentence, and explain what that means for a claim like *"the
#    average country spends \$1,010 per person on health"*. For example, does that mean an average person spend \$1,010 on health?
# 2. Name **two** columns in this table you would not put into a model that ranked countries, and
#    explain why. Missing values are one good reason; they are not the only one.
# 3. This table is tidy. Name the rule that makes it tidy that a wide table of
#    `2008 | 2009 | 2010` columns would break.
#
# > ✏️ **Answer in Canvas** — *Week 1 Homework - Data Understanding*, question **(c)**.

# %% [markdown]
# ---
# # Part 5 · The Analyst's Note
#
# **About 150 words. This is worth a meaningful share of the grade.**
#
# You work for a foundation that is about to fund a health program in five countries with poor health care. A colleague has
# already picked them: she sorted this table by `Health Exp/Capita`, took the five lowest, and has put
# them in a slide for Thursday.
#
# Write her a note saying whether that list can stand.
#
# A good note:
#
# - gives her **a decision** — use the list, change it, or do not use it — not a summary of what you
#   looked at
# - quotes **numbers from your own output above** as the support for your decision
# - names **specifics** that would make the list wrong, not data quality in general
# - does not use the words *skew*, *outlier*, *null*, *NaN* or *describe*
#
# That last constraint is not a style exercise. The person who has to act on this has not taken this
# course, and if you can only explain the problem in the vocabulary of the course, you cannot yet
# explain it to her.

# %% [markdown]
# > ✏️ **Answer in Canvas** — *Week 1 Homework - Data Understanding*, question **The Analyst's Note**.

# %% [markdown]
# ---
# ### Before you submit
#
# - [ ] **Runtime → Restart session and run all.** It must run top to bottom with no errors.
# - [ ] Every `____` filled in.
# - [ ] All nine answers submitted in the Canvas quiz **Week 1 Homework - Data Understanding** — the five numeric checks,
#       (a), (b), (c), and the note.
# - [ ] This notebook shared — **Share → General access → Anyone with the link** — and its link pasted
#       into the quiz's first question. Check it opens in a private window.
# - [ ] Any cells an AI left behind, out of order or duplicated, cleaned up.
# - [ ] Your name in the filename.
